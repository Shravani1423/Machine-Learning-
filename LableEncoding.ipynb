# %%
import pandas as pd

# %%
df =pd.DataFrame({"name":["black","cow","cat","dog","wscube"]})
df
# Out:
#      name
# 0   black
# 1     cow
# 2     cat
# 3     dog
# 4  wscube

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df["en_name"] = le.fit_transform(df["name"])

# %%
df
# Out:
#      name  en_name
# 0   black        0
# 1     cow        2
# 2     cat        1
# 3     dog        3
# 4  wscube        4

# %%
dataset= pd.read_csv("Data.csv")
dataset.head(3)
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0       35.0            NaN  33.6
# 1         1     85.0          66.0       29.0            NaN  26.6
# 2         8    183.0          64.0        NaN            NaN  23.3
#
#    Diabetes_Pedigree  Age  Class
# 0              0.627   50      1
# 1              0.351   31      0
# 2              0.672   32      1

# %%
dataset["Diastolic_BP"].unique()
# Out:
# array([ 72.,  66.,  64.,  40.,  74.,  50.,  nan,  70.,  96.,  92.,  80.,
#         60.,  84.,  30.,  88.,  90.,  94.,  76.,  82.,  75.,  58.,  78.,
#         68., 110.,  56.,  62.,  85.,  86.,  48.,  44.,  65., 108.,  55.,
#        122.,  54.,  52.,  98., 104.,  95.,  46., 102., 100.,  61.,  24.,
#         38., 106., 114.])

# %%
la = LabelEncoder()
la.fit(dataset["Diastolic_BP"])
# Out:
# LabelEncoder()

# %%
la.transform(dataset["Diastolic_BP"])
# Out:
# array([21, 18, 16, 18,  3, 22,  7, 46, 20, 36, 33, 22, 26, 13, 21, 46, 28,
#        22,  1, 20, 31, 28, 32, 26, 34, 20, 24, 18, 27, 33, 23, 24, 12, 33,
#        25, 13, 24, 24, 19, 21, 16, 28, 33, 43, 16, 18, 11, 20, 18, 46, 26,
#         7, 18, 32, 18,  7, 19, 31, 27, 16, 46, 21, 15, 12, 18, 22, 31, 33,
#        18, 29, 18, 16, 32, 30, 23,  6, 25, 21, 46, 18,  4, 46, 25, 17, 42,
#        22, 21, 19, 20, 19, 10, 26, 25, 21, 27, 21, 15,  6,  7, 32, 21, 13,
#        36, 21, 17, 11, 45, 12, 12, 29, 21, 15, 24, 15,  9, 33, 22,  6, 13,
#        24, 24, 16, 22, 26, 24,  1, 20, 12, 31, 28, 20, 11, 16, 22, 19, 13,
#        20, 13, 26, 21, 25, 27,  8, 18, 15, 23, 26, 16, 25, 20, 22, 17, 30,
#        27, 25, 31,  8, 11, 22, 21, 32, 22, 26, 16, 31, 22, 18, 19, 18, 32,
#        27, 20, 46, 13, 16, 21, 25, 43, 25, 27, 26, 16, 22, 13, 22, 19, 19,
#        37, 24, 26, 15, 20, 18, 46, 10, 28, 12, 15, 16, 13, 26, 27, 19, 20,
# ...
